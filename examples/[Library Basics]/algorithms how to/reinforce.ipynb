# %%
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
import torch_optimizer as optim

import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from time import gmtime, strftime

from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline


# == recnn ==
import sys
sys.path.append("../../../")
import recnn

cuda = torch.device('cuda')

# ---
frame_size = 10
batch_size = 10
n_epochs   = 100
plot_every = 30
num_items    = 5000 # n items to recommend. Can be adjusted for your vram 
# --- 

tqdm.pandas()


from jupyterthemes import jtplot
jtplot.style(theme='grade3')

# %%
def embed_batch(batch, item_embeddings_tensor, *args, **kwargs):
    return recnn.data.batch_contstate_discaction(batch, item_embeddings_tensor,
                                                 frame_size=frame_size, num_items=num_items)

    
def prepare_dataset(args_mut, kwargs):
    kwargs.set('reduce_items_to', num_items) # set kwargs for your functions here!
    pipeline = [recnn.data.truncate_dataset, recnn.data.prepare_dataset]
    recnn.data.build_data_pipeline(pipeline, kwargs, args_mut)
    
frame_size = 10
batch_size = 25
# embeddgings: https://drive.google.com/open?id=1EQ_zXBR3DKpmJR3jBgLvt-xoOvArGMsL
dirs = recnn.data.env.DataPath(
    base="../../../data/",
    embeddings="embeddings/ml20_pca128.pkl",
    ratings="ml-20m/ratings.csv",
    cache="cache/frame_env.pkl",
    use_cache=True
)
env = recnn.data.env.FrameEnv(dirs, frame_size, batch_size)
# Out:
# 0%|          | 0/18946308 [00:00<?, ?it/s]action space is reduced to 26744 - 21744 = 5000
# 100%|██████████| 18946308/18946308 [00:12<00:00, 1506930.19it/s]
# 100%|██████████| 18946308/18946308 [00:14<00:00, 1320979.40it/s]
# 100%|██████████| 138493/138493 [00:07<00:00, 19389.51it/s]

# %%
class Beta(nn.Module):
    def __init__(self):
        super(Beta, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(1290, num_items),
            nn.Softmax()
        )
        self.optim = optim.RAdam(self.net.parameters(), lr=1e-5, weight_decay=1e-5)
        self.criterion = nn.CrossEntropyLoss()
        
    def forward(self, state, action):
        
        predicted_action = self.net(state)
        
        loss = self.criterion(predicted_action, action.argmax(1))
        
        self.optim.zero_grad()
        loss.backward()
        self.optim.step()
        
        return predicted_action.detach()

# %%
beta_net   = Beta().to(cuda)
value_net  = recnn.nn.Critic(1290, num_items, 2048, 54e-2).to(cuda)
policy_net = recnn.nn.DiscreteActor(1290, num_items, 2048).to(cuda)
policy_net.action_source = {'pi': 'beta', 'beta': 'beta'}

reinforce = recnn.nn.Reinforce(policy_net, value_net)
reinforce = reinforce.to(cuda)

reinforce.writer = SummaryWriter(log_dir='../../../runs/Reinforce{}/'.format(strftime("%H_%M", gmtime())))
plotter = recnn.utils.Plotter(reinforce.loss_layout, [['value', 'policy']],)

# %%
from recnn.nn import ChooseREINFORCE

def select_action_corr(state, action, K, writer, step, **kwargs):
    # note here I provide beta_net forward in the arguments
    return reinforce.nets['policy_net']._select_action_with_correction(state, beta_net.forward, action,
                                                                            K=K, writer=writer,
                                                                            step=step)

reinforce.nets['policy_net'].select_action = select_action_corr
reinforce.params['reinforce'] = ChooseREINFORCE(ChooseREINFORCE.reinforce_with_correction)
reinforce.params['K'] = 10

# %%
pbar = tqdm(env.train_dataloader)
# Out:
# 0%|          | 0/13155 [00:00<?, ?it/s]

# %%
reinforce._step = 0
for epoch in range(n_epochs):
    for batch in env.train_dataloader:
        pbar.update(1)
        loss = reinforce.update(batch)
        reinforce.step()
        if loss:
            plotter.log_losses(loss)
        if reinforce._step % plot_every == 0:
            clear_output(True)
            print('step', reinforce._step)
            plotter.plot_loss()
        if reinforce._step > 4000:
            break
            # assert False
# Out:
# step 510
# 7%|▋         | 892/13155 [01:32<27:23,  7.46it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c51e2f23ef48> in <module>
#       5     for batch in env.train_dataloader:
#       6         pbar.update(1)
# ----> 7         loss = reinforce.update(batch)
#       8         reinforce.step()
#       9         if loss:
#
# ~/Documents/programming/python/RecNN/recnn/nn/algo.py in update(self, batch, learn)
#      47
#      48     def update(self, batch, learn=True):
# ---> 49         return self.algorithm(batch, self.params, self.nets, self.optimizers,
#      50                               device=self.device, debug=self.debug, writer=self.writer,
#      51                               learn=learn, step=self._step)
#
# ~/Documents/programming/python/RecNN/recnn/nn/update/reinforce.py in reinforce_update(batch, params, nets, optimizer, device, debug, writer, learn, step)
#      72     state, action, reward, next_state, done = data.get_base_batch(batch)
#      73
# ---> 74     predicted_probs = nets['policy_net'].select_action(state=state, action=action, K=params['K'],
#      75                                                        learn=learn, writer=writer, step=step)
#      76     writer.add_histogram('predicted_probs_std', predicted_probs.std(), step)
#
# <ipython-input-5-e87ad1747c3a> in select_action_corr(state, action, K, writer, step, **kwargs)
#       3 def select_action_corr(state, action, K, writer, step, **kwargs):
#       4     # note here I provide beta_net forward in the arguments
# ----> 5     return reinforce.nets['policy_net']._select_action_with_correction(state, beta_net.forward, action,
#       6                                                                             K=K, writer=writer,
#       7                                                                             step=step)
#
# ~/Documents/programming/python/RecNN/recnn/nn/models.py in _select_action_with_correction(self, state, beta, action, writer, step, **kwargs)
#     143
#     144     def _select_action_with_correction(self, state, beta, action, writer, step, **kwargs):
# --> 145         pi_log_prob, beta_log_prob, pi_probs = self.pi_beta_sample(state, beta, action)
#     146
#     147         # calculate correction
#
# ~/Documents/programming/python/RecNN/recnn/nn/models.py in pi_beta_sample(self, state, beta, action, **kwargs)
#     119         # 1. obtain probabilities
#     120         # note: detach is to block gradient
# --> 121         beta_probs = beta(state.detach(), action=action)
#     122         pi_probs = self.forward(state)
#     123
#
# <ipython-input-3-54631dad1970> in forward(self, state, action)
#      16
#      17         self.optim.zero_grad()
# ---> 18         loss.backward()
#      19         self.optim.step()
#      20
#
# ~/anaconda3/envs/recnn/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~/anaconda3/envs/recnn/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     123         retain_graph = create_graph
#     124
# --> 125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
#     127         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
torch.save(reinforce.nets['policy_net'].state_dict(), '../../../models/reinforce_policy.model')
torch.save(reinforce.nets['value_net'].state_dict(), '../../../models/reinforce_value.model')
